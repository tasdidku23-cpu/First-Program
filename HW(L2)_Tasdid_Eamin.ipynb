# %% [markdown]
# <a href="https://colab.research.google.com/github/tasdidku23-cpu/First-Program/blob/HW---L2/HW(L2)_Tasdid_Eamin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating variables
name = "Tasdid Eamin"
age = 23
favorite_color = "Blue"
height = 5.7
# Printing Variables
print("Name:", name)
print("Age:", age)
print("Favorite Color:", favorite_color)
print("Height:", height)
# Out:
# Name: Tasdid Eamin
# Age: 23
# Favorite Color: Blue
# Height: 5.7

# %%
# Variables
name = "Tasdid Eamin"
address = "Khulna"
age = 23
weight = 70.5
price = 2025.11
is_student = True
has_paid = False
result = None

# Checking variable's type
print(type(name))       #str
print(type(address))    #str
print(type(age))        #int
print(type(weight))     #float
print(type(price))      #float
print(type(is_student)) #bool
print(type(has_paid))   #bool
print(type(result))     #nonetype
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# <class 'NoneType'>

# %%
# Arithmatic Operations
x = 10
y = 6
print(x+y)      # Addition: 16
print(x-y)      # Subtraction: 4
print(x*y)      # Multiplication: 60
print(x/y)      # Division: 1.67
print(x//y)     # Floor Division: 1
print(x%y)      # Modulus (Reminder): 4
print(x**y)     # Exponentiation: 1000000

# String Operations
first = "Tasdid"
last = "Eamin"
# Concatenation
full = first+" "+last
print(full)       # Tasdid Eamin
# Repetition
repeated = first*5
print(repeated)   # TasdidTasdidTasdidTasdidTasdid
# Length
print(len(first)) # 6
print(len(last))  # 5
print(len(full))  # 12

# Homework (Lecture 2)
length = 7
width = 5
area = length*width
print(area)       #35
# Out:
# 16
# 4
# 60
# 1.6666666666666667
# 1
# 4
# 1000000
# Tasdid Eamin
# TasdidTasdidTasdidTasdidTasdid
# 6
# 5
# 12
# 35
