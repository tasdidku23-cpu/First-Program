# %% [markdown]
# <a href="https://colab.research.google.com/github/tasdidku23-cpu/First-Program/blob/main/Homework_(L3)_Tasdid_Eamin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework (L3) - Tasdid Eamin**

# %% [markdown]
# ## **Assignments - Conditional**

# %%
# Assignment 1 (Basic if-else Statement)
age = int(input("Enter your age: "))
if age >= 18:
  print("You are eligible")
else:
  print("You aren't eligible")
# Out:
# Enter your age: 18
# You are eligible

# %%
# Assignment 2 (Nested if-else)
temperature = int(input("Enter temperature(in number): "))
if temperature >= 0:
  if temperature == 0:
    print("Zero")
  else:
    print("Positive Temperature")
else:
  print("Negative Temperature")
# Out:
# Enter temperature(in number): 5
# Positive Temperature

# %%
# Assignment 3 (Conditional Expressons)
number = int(input("Enter a number: "))
if number % 2 == 0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter a number: 7
# Odd Number

# %%
# Assignment 4 (Age Group Classification)
age = int(input("Enter your age: "))
if age <= 12:
  print("Child")
elif age >= 13 and age <= 19:
  print("Teenager")
elif age >= 20 and age <= 64:
  print("Adult")
else:
  print("Senior")
# Out:
# Enter your age: 23
# Adult

# %% [markdown]
# ## **Assignments - Loops and Functions**

# %%
# Assignment 1 (Sum of natural numbers)
def sum_of_natural_numbers(n):
  total = 0
  for i in range(1, n + 1):
    total += i
  return total
print("Sum = ", sum_of_natural_numbers(6))

# I took help from ChatGPT to understand this task, then solved by myself.
# Out:
# Sum =  21

# %%
# Assignment 2 (Factorial of a number)
def factorial(n):
  result = 1
  for i in range(1, n + 1):
    result *= i
  return result
print("Factorial = ", factorial(6))

# I took help from ChatGPT to understand this task, then solved by myself.
# Out:
# Factorial =  720

# %%
# Assignment 3 (Multiplication Table)
def multiplication_table(n):
    for i in range(1, 11):
      product = n * i
      print(f"{n} * {i} = {product}")

multiplication_table(7)

# I took help from ChatGPT to understand this task, then solved by myself.
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
